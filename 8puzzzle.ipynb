# %% [markdown]
# <a href="https://colab.research.google.com/github/arin-dsouza/AI-LAB/blob/main/1BM22CS052(8puzzzle).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import copy

def find_blank_position(state):
    for i in range(len(state)):
        for j in range(len(state[i])):
            if state[i][j] == 0:
                return i, j

def get_possible_moves(state):
    moves = []
    row, col = find_blank_position(state)
    if row > 0:
        moves.append((row - 1, col))
    if row < 2:
        moves.append((row + 1, col))
    if col > 0:
        moves.append((row, col - 1))
    if col < 2:
        moves.append((row, col + 1))
    return moves

def move_tile(state, new_row, new_col):
    row, col = find_blank_position(state)
    new_state = copy.deepcopy(state)
    new_state[row][col], new_state[new_row][new_col] = new_state[new_row][new_col], new_state[row][col]
    return new_state

def dfs_with_limit(state, goal, depth, visited):
    if state == goal:
        return True
    if depth == 0:
        return False

    visited.append(state)
    possible_moves = get_possible_moves(state)

    for move in possible_moves:
        new_state = move_tile(state, move[0], move[1])
        if new_state not in visited:
            if dfs_with_limit(new_state, goal, depth - 1, visited):
                return True
    visited.pop()
    return False

def ids(start, goal):
    depth = 0
    while True:
        visited = []
        if dfs_with_limit(start, goal, depth, visited):
            return visited
        depth += 1

def display_state(state):
    for row in state:
        print(row)
    print()


start_state = [
    [1, 2, 3],
    [4, 0, 6],
    [7, 5, 8]
]

goal_state = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
]

if __name__ == '__main__':
    print("Initial State:")
    display_state(start_state)

    print("Goal State:")
    display_state(goal_state)

    result = ids(start_state, goal_state)
    if result:
        print("Solution Found! Steps:")
        for step in result:
            display_state(step)
    else:
        print("No solution exists!")
# Out:
# Initial State:
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# Goal State:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
#
# Solution Found! Steps:
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]

# %%
from collections import deque

goal_state = [[1, 2, 3], [4, 5, 6], [7, 8, 0]]

moves = {
    (0, 1): "Right",
    (0, -1): "Left",
    (1, 0): "Down",
    (-1, 0): "Up"
}

def is_goal(state):
    return state == goal_state

def dfs(state):
    from collections import deque
    visited = set()
    stack = deque([(state, [])])

    while stack:
        state, path = stack.pop()
        if is_goal(state):
            return path + [(state, "Goal")]
        state_tuple = tuple(map(tuple, state))
        if state_tuple not in visited:
            visited.add(state_tuple)
            for i in range(3):
                for j in range(3):
                    if state[i][j] == 0:
                        for move, direction in moves.items():
                            new_i, new_j = i + move[0], j + move[1]
                            if 0 <= new_i < 3 and 0 <= new_j < 3:
                                new_state = [row[:] for row in state]
                                new_state[i][j], new_state[new_i][new_j] = new_state[new_i][new_j], new_state[i][j]

                                stack.append((new_state, path + [(state, direction)]))
    return None

def print_solution(solution):
    if solution:
        print("Solution found:")
        for i, (state, direction) in enumerate(solution[1:]):
            print(f"Move {i}: {direction}")
            for row in state:
                print(row)
            print()
    else:
        print("No solution found")


initial_state = [[1, 2, 3], [4, 5, 6], [0, 7, 8]]
solution = dfs(initial_state)
print_solution(solution)
# Out:
# Solution found:
# Move 0: Up
# [1, 2, 3]
# [0, 5, 6]
# [4, 7, 8]
#
# Move 1: Right
# [0, 2, 3]
# [1, 5, 6]
# [4, 7, 8]
#
# Move 2: Down
# [2, 0, 3]
# [1, 5, 6]
# [4, 7, 8]
#
# Move 3: Down
# [2, 5, 3]
# [1, 0, 6]
# [4, 7, 8]
#
# Move 4: Left
# [2, 5, 3]
# [1, 7, 6]
# [4, 0, 8]
#
# Move 5: Up
# [2, 5, 3]
# [1, 7, 6]
# [0, 4, 8]
#
# Move 6: Up
# [2, 5, 3]
# [0, 7, 6]
# [1, 4, 8]
#
# Move 7: Right
# [0, 5, 3]
# [2, 7, 6]
# [1, 4, 8]
#
# Move 8: Down
# [5, 0, 3]
# [2, 7, 6]
# [1, 4, 8]
#
# Move 9: Down
# [5, 7, 3]
# [2, 0, 6]
# [1, 4, 8]
#
# Move 10: Left
# [5, 7, 3]
# [2, 4, 6]
# [1, 0, 8]
#
# Move 11: Up
# [5, 7, 3]
# [2, 4, 6]
# [0, 1, 8]
#
# Move 12: Up
# [5, 7, 3]
# [0, 4, 6]
# [2, 1, 8]
#
# Move 13: Right
# [0, 7, 3]
# [5, 4, 6]
# [2, 1, 8]
#
# Move 14: Down
# [7, 0, 3]
# [5, 4, 6]
# [2, 1, 8]
#
# Move 15: Down
# [7, 4, 3]
# [5, 0, 6]
# [2, 1, 8]
#
# Move 16: Left
# [7, 4, 3]
# [5, 1, 6]
# [2, 0, 8]
#
# Move 17: Up
# [7, 4, 3]
# [5, 1, 6]
# [0, 2, 8]
#
# Move 18: Up
# [7, 4, 3]
# [0, 1, 6]
# [5, 2, 8]
#
# Move 19: Right
# [0, 4, 3]
# [7, 1, 6]
# [5, 2, 8]
#
# Move 20: Down
# [4, 0, 3]
# [7, 1, 6]
# [5, 2, 8]
#
# Move 21: Down
# [4, 1, 3]
# [7, 0, 6]
# [5, 2, 8]
#
# Move 22: Left
# [4, 1, 3]
# [7, 2, 6]
# [5, 0, 8]
#
# Move 23: Up
# [4, 1, 3]
# [7, 2, 6]
# [0, 5, 8]
#
# Move 24: Up
# [4, 1, 3]
# [0, 2, 6]
# [7, 5, 8]
#
# Move 25: Right
# [0, 1, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# Move 26: Down
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# Move 27: Down
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# Move 28: Right
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# Move 29: Goal
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
